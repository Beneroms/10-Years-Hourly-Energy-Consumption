# %% [markdown]
# <a href="https://colab.research.google.com/github/Beneroms/10-Years-Hourly-Energy-Consumption/blob/main/Energy_Consumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Analysis and Visualization of 10 Years Hourly Energy Consumption Using Python, Seaborn, And Pandas.**

# %% [markdown]
# Step 1:
# Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import datetime
# %matplotlib inline

# %% [markdown]
# Step 2:
# Read the DataSet

# %%
df = pd.read_csv("AEP_hourly.csv")
df.head(3)
# Out:
#               Datetime   AEP_MW
# 0  2004-12-31 01:00:00  13478.0
# 1  2004-12-31 02:00:00  12865.0
# 2  2004-12-31 03:00:00  12577.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121273 entries, 0 to 121272
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  121273 non-null  object
#  1   AEP_MW    121273 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#               AEP_MW
# count  121273.000000
# mean    15499.513717
# std      2591.399065
# min      9581.000000
# 25%     13630.000000
# 50%     15310.000000
# 75%     17200.000000
# max     25695.000000

# %% [markdown]
# Step 3:
# Seperate date and time

# %%
df["New_Date"] = pd.to_datetime(df["Datetime"]).dt.date
df["New_Time"] = pd.to_datetime(df["Datetime"]).dt.time

# %%
df1 = df
df1.head(2)
# Out:
#               Datetime   AEP_MW    New_Date  New_Time
# 0  2004-12-31 01:00:00  13478.0  2004-12-31  01:00:00
# 1  2004-12-31 02:00:00  12865.0  2004-12-31  02:00:00

# %% [markdown]
# Step 4:
#
# When was the higest Energy Consumption and which Year

# %% [markdown]
# Maximum

# %%
df1[df1["AEP_MW"] == df["AEP_MW"].max()]
# Out:
#                   Datetime   AEP_MW    New_Date  New_Time
# 30221  2008-10-20 14:00:00  25695.0  2008-10-20  14:00:00

# %% [markdown]
# Minimum

# %%
df1[df1["AEP_MW"] == df["AEP_MW"].min()]
# Out:
#                    Datetime  AEP_MW    New_Date  New_Time
# 100759  2016-10-02 05:00:00  9581.0  2016-10-02  05:00:00

# %% [markdown]
# Step 5:
#
# Plot and Data visualization

# %%
sns.distplot(df1["AEP_MW"])
# Out:
# <ipython-input-9-8a3bf090b81a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1["AEP_MW"])
# <Axes: xlabel='AEP_MW', ylabel='Density'>

# %% [markdown]
# The sns.distplot function has been deprecated in Seaborn and replaced by sns.histplot and sns.displot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df1["AEP_MW"], kde=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(df1["AEP_MW"], kde=True)
plt.show()

# %% [markdown]
# Step 7:
#
# Extract Date and Time

# %%
df1["Year"] = pd.DatetimeIndex(df['New_Date']).year
df1.head(2)
# Out:
#               Datetime   AEP_MW    New_Date  New_Time  Year
# 0  2004-12-31 01:00:00  13478.0  2004-12-31  01:00:00  2004
# 1  2004-12-31 02:00:00  12865.0  2004-12-31  02:00:00  2004

# %% [markdown]
# Relationship - Energy vs Year

# %%
sns.lineplot(x=df1["Year"],y=df1["AEP_MW"], data=df1)
# Out:
# <Axes: xlabel='Year', ylabel='AEP_MW'>

# %% [markdown]
# Regression

# %%
sns.jointplot(x=df1["Year"],
              y=df1["AEP_MW"],
              data=df1,
             kind="reg")

# %%
sns.jointplot(x=df1["Year"],
              y=df1["AEP_MW"],
              data=df1,
             kind="kde")

# %% [markdown]
# Relationship between Energy and Time

# %%
df1.head(2)
# Out:
#               Datetime   AEP_MW    New_Date  New_Time  Year
# 0  2004-12-31 01:00:00  13478.0  2004-12-31  01:00:00  2004
# 1  2004-12-31 02:00:00  12865.0  2004-12-31  02:00:00  2004
